# %%
import lightgbm as lgb
import numpy as np
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, matthews_corrcoef

# %%
# Path to the folder containing your .csv and .57pfeatures files
folder_path = '/home/tzejet/drb_jet/output_features'

# Path to the full_ids.txt file
full_ids_path = '/home/tzejet/drb_jet/full_ids.txt'

# Read the list of file prefixes from full_ids.txt
with open(full_ids_path, 'r') as f:
    file_prefixes = [line.strip() for line in f.readlines()]

# Loop through each prefix from the full_ids.txt file
for prefix in file_prefixes:
    # Construct the expected file names for .csv and .57pfeatures
    csv_file_name = f"{prefix}.csv"
    pfeatures_file_name = f"{prefix}.57pfeatures"
    
    # Check if both the .csv and .57pfeatures files exist in the folder
    csv_file_path = os.path.join(folder_path, csv_file_name)
    pfeatures_file_path = os.path.join(folder_path, pfeatures_file_name)
    
    if os.path.exists(csv_file_path) and os.path.exists(pfeatures_file_path):
        # Load the .csv file
        csv_file = pd.read_csv(csv_file_path, header=0)
        
        # Drop the first four columns from the .csv file
        csv_file = csv_file.iloc[:, 4:]
        
        # Load the .57pfeatures file (assuming it's space-separated and text-based)
        with open(pfeatures_file_path, 'r') as pfeatures_file:
            pfeatures_data = pfeatures_file.readlines()[1: ]  # Remove the header
        
        # Remove any '+' characters and convert to numerical format
        pfeatures_array = np.array([list(map(float, line.replace('+', '').split()[1:])) for line in pfeatures_data])
        
        # Convert the .csv data to a NumPy array
        csv_array = csv_file.to_numpy()
        
        # Concatenate the .57pfeatures array and the .csv array row-wise (column-wise merge)
        combined_array = np.hstack((pfeatures_array, csv_array))
        
        # Save the combined array to a new file (or any desired format)
        output_file_name = f"{prefix}_combined.csv"
        output_file_path = os.path.join(folder_path, output_file_name)
        np.savetxt(output_file_path, combined_array, delimiter=',', fmt='%.6f')
        
        print(f"Processed and saved combined file: {output_file_name}")
    else:
        print(f"Missing .csv or .57pfeatures file for prefix: {prefix}")

print("Processing completed!")
# Out:
# Processed and saved combined file: 1A340_combined.csv
# Processed and saved combined file: 1A350_combined.csv
# Processed and saved combined file: 1A3Q1_combined.csv
# Processed and saved combined file: 1A9N1_combined.csv
# Processed and saved combined file: 1A9N2_combined.csv
# Processed and saved combined file: 1AIS0_combined.csv
# Processed and saved combined file: 1AKH1_combined.csv
# Processed and saved combined file: 1AM91_combined.csv
# Processed and saved combined file: 1AU71_combined.csv
# Processed and saved combined file: 1AWC0_combined.csv
# Processed and saved combined file: 1B2M1_combined.csv
# Processed and saved combined file: 1B3T0_combined.csv
# Processed and saved combined file: 1B720_combined.csv
# Processed and saved combined file: 1BDT2_combined.csv
# Processed and saved combined file: 1BG10_combined.csv
# Processed and saved combined file: 1BL00_combined.csv
# Processed and saved combined file: 1BRN0_combined.csv
# Processed and saved combined file: 1BY41_combined.csv
# Processed and saved combined file: 1C0A0_combined.csv
# Processed and saved combined file: 1C9S18_combined.csv
# Processed and saved combined file: 1CKT0_combined.csv
# Processed and saved combined file: 1CW00_combined.csv
# Processed and saved combined file: 1D020_combined.csv
# Processed and saved combined file: 1D3U1_combined.csv
# Processed and saved combined file: 1DC10_combined.csv
# Processed and saved combined file: 1DFM1_combined.csv
# Processed and saved combined file: 1DFU0_combined.csv
# Processed and saved combined file: 1DI20_combined.csv
# Processed and saved combined file: 1DIZ0_combined.csv
# Processed and saved combined file: 1DMU0_combined.csv
# Processed and saved combined file: 1DNK0_combined.csv
# Processed and saved combined file: 1DP70_combined.csv
# Processed and saved combined file: 1DSZ0_combined.csv
# Processed and saved combined file: 1DUX1_combined.csv
# Processed and saved combined file: 1E3O0_combined.csv
# Processed and saved combined file: 1EC61_combined.csv
# Processed and saved combined file: 1EGW1_combined.csv
# Processed and saved combined file: 1EMH0_combined.csv
# Processed and saved combined file: 1EWQ0_combined.csv
# Processed and saved combined file: 1EYU1_combined.csv
# Processed and saved combined file: 1F7U0_combined.csv
# Processed and saved combined file: 1FEU0_combined.csv
# Processed and saved combined file: 1FIU3_combined.csv
# Processed and saved combined file: 1FJL0_combined.csv
# Processed and saved combined file: 1GA52_combined.csv
# Processed and saved combined file: 1GD22_combined.csv
# Processed and saved combined file: 1GXP1_combined.csv
# Processed and saved combined file: 1H2C0_combined.csv
# Processed and saved combined file: 1H6F1_combined.csv
# Processed and saved combined file: 1H892_combined.csv
# Processed and saved combined file: 1H8A0_combined.csv
# Processed and saved combined file: 1HCQ0_combined.csv
# Processed and saved combined file: 1HCR0_combined.csv
# Processed and saved combined file: 1HLV0_combined.csv
# Processed and saved combined file: 1HQ10_combined.csv
# Processed and saved combined file: 1HWT1_combined.csv
# Processed and saved combined file: 1I7D0_combined.csv
# Processed and saved combined file: 1IAW1_combined.csv
# Processed and saved combined file: 1IG70_combined.csv
# Processed and saved combined file: 1IGN0_combined.csv
# Processed and saved combined file: 1IHF1_combined.csv
# Processed and saved combined file: 1IPP0_combined.csv
# Processed and saved combined file: 1J1U0_combined.csv
# Processed and saved combined file: 1J1V0_combined.csv
# Processed and saved combined file: 1J3E0_combined.csv
# Processed and saved combined file: 1J590_combined.csv
# Processed and saved combined file: 1JBR1_combined.csv
# Processed and saved combined file: 1JE81_combined.csv
# Processed and saved combined file: 1JEY0_combined.csv
# Processed and saved combined file: 1JEY1_combined.csv
# Processed and saved combined file: 1JGG0_combined.csv
# Processed and saved combined file: 1JID0_combined.csv
# Processed and saved combined file: 1JJ210_combined.csv
# Processed and saved combined file: 1JJ211_combined.csv
# Processed and saved combined file: 1JJ213_combined.csv
# Processed and saved combined file: 1JJ220_combined.csv
# Processed and saved combined file: 1JJ224_combined.csv
# Processed and saved combined file: 1JJ27_combined.csv
# Processed and saved combined file: 1JJ40_combined.csv
# Processed and saved combined file: 1JMC0_combined.csv
# Processed and saved combined file: 1K780_combined.csv
# Processed and saved combined file: 1K820_combined.csv
# Processed and saved combined file: 1K8W0_combined.csv
# Processed and saved combined file: 1KFS0_combined.csv
# Processed and saved combined file: 1KNZ4_combined.csv
# Processed and saved combined file: 1KU70_combined.csv
# Processed and saved combined file: 1KX52_combined.csv
# Processed and saved combined file: 1KX53_combined.csv
# Processed and saved combined file: 1KX55_combined.csv
# Processed and saved combined file: 1L3L1_combined.csv
# Processed and saved combined file: 1LAU0_combined.csv
# Processed and saved combined file: 1LE80_combined.csv
# Processed and saved combined file: 1LLM1_combined.csv
# Processed and saved combined file: 1LNG0_combined.csv
# Processed and saved combined file: 1LQ13_combined.csv
# Processed and saved combined file: 1M070_combined.csv
# Processed and saved combined file: 1M5R1_combined.csv
# Processed and saved combined file: 1MEY1_combined.csv
# Processed and saved combined file: 1MJI1_combined.csv
# Processed and saved combined file: 1MJQ0_combined.csv
# Processed and saved combined file: 1MNM1_combined.csv
# Processed and saved combined file: 1MNM2_combined.csv
# Processed and saved combined file: 1MWI0_combined.csv
# Processed and saved combined file: 1NH22_combined.csv
# Processed and saved combined file: 1NKP0_combined.csv
# Processed and saved combined file: 1NKP3_combined.csv
# Processed and saved combined file: 1NLW2_combined.csv
# Processed and saved combined file: 1NOP0_combined.csv
# Processed and saved combined file: 1NOY1_combined.csv
# Processed and saved combined file: 1NVP2_combined.csv
# Processed and saved combined file: 1OE50_combined.csv
# Processed and saved combined file: 1OJ80_combined.csv
# Processed and saved combined file: 1OOA1_combined.csv
# Processed and saved combined file: 1ORN0_combined.csv
# Processed and saved combined file: 1OUP0_combined.csv
# Processed and saved combined file: 1OZJ0_combined.csv
# Processed and saved combined file: 1P511_combined.csv
# Processed and saved combined file: 1PH60_combined.csv
# Processed and saved combined file: 1PH61_combined.csv
# Processed and saved combined file: 1PP70_combined.csv
# Processed and saved combined file: 1PUE1_combined.csv
# Processed and saved combined file: 1PUF0_combined.csv
# Processed and saved combined file: 1PUF1_combined.csv
# Processed and saved combined file: 1QAI1_combined.csv
# Processed and saved combined file: 1QLN0_combined.csv
# Processed and saved combined file: 1QN71_combined.csv
# Processed and saved combined file: 1QPI0_combined.csv
# Processed and saved combined file: 1QPS0_combined.csv
# Processed and saved combined file: 1QPZ0_combined.csv
# Processed and saved combined file: 1QRV0_combined.csv
# Processed and saved combined file: 1QU20_combined.csv
# Processed and saved combined file: 1QUM0_combined.csv
# Processed and saved combined file: 1QZH0_combined.csv
# Processed and saved combined file: 1R3E0_combined.csv
# Processed and saved combined file: 1R4O0_combined.csv
# Processed and saved combined file: 1R713_combined.csv
# Processed and saved combined file: 1R7M1_combined.csv
# Processed and saved combined file: 1R8E0_combined.csv
# Processed and saved combined file: 1RH61_combined.csv
# Processed and saved combined file: 1RIO1_combined.csv
# Processed and saved combined file: 1RPU0_combined.csv
# Processed and saved combined file: 1RRC0_combined.csv
# Processed and saved combined file: 1RTA0_combined.csv
# Processed and saved combined file: 1RXW0_combined.csv
# Processed and saved combined file: 1S7212_combined.csv
# Processed and saved combined file: 1S7215_combined.csv
# Processed and saved combined file: 1S7217_combined.csv
# Processed and saved combined file: 1S7222_combined.csv
# Processed and saved combined file: 1SA31_combined.csv
# Processed and saved combined file: 1SDS0_combined.csv
# Processed and saved combined file: 1SFU1_combined.csv
# Processed and saved combined file: 1SKN0_combined.csv
# Processed and saved combined file: 1STX0_combined.csv
# Processed and saved combined file: 1T2T0_combined.csv
# Processed and saved combined file: 1TC30_combined.csv
# Processed and saved combined file: 1TEZ1_combined.csv
# Processed and saved combined file: 1TRR3_combined.csv
# Processed and saved combined file: 1U0B0_combined.csv
# Processed and saved combined file: 1U8B0_combined.csv
# Processed and saved combined file: 1UUT1_combined.csv
# Processed and saved combined file: 1UVJ0_combined.csv
# Processed and saved combined file: 1V153_combined.csv
# Processed and saved combined file: 1VQ717_combined.csv
# Processed and saved combined file: 1VQ722_combined.csv
# Processed and saved combined file: 1VQ727_combined.csv
# Processed and saved combined file: 1VQ91_combined.csv
# Processed and saved combined file: 1VQK4_combined.csv
# Processed and saved combined file: 1VQK7_combined.csv
# Processed and saved combined file: 1VQL6_combined.csv
# Processed and saved combined file: 1VQM5_combined.csv
# Processed and saved combined file: 1VQN12_combined.csv
# Processed and saved combined file: 1VQO3_combined.csv
# Processed and saved combined file: 1VQP0_combined.csv
# Processed and saved combined file: 1VQP18_combined.csv
# Processed and saved combined file: 1VQP2_combined.csv
# Processed and saved combined file: 1VTN0_combined.csv
# Processed and saved combined file: 1W0T1_combined.csv
# Processed and saved combined file: 1W0U0_combined.csv
# Processed and saved combined file: 1WD10_combined.csv
# Processed and saved combined file: 1WTE_M10_combined.csv
# Processed and saved combined file: 1X9M0_combined.csv
# Processed and saved combined file: 1XBR0_combined.csv
# Processed and saved combined file: 1XHV1_combined.csv
# Processed and saved combined file: 1Y8Z0_combined.csv
# Processed and saved combined file: 1YF31_combined.csv
# Processed and saved combined file: 1YHQ26_combined.csv
# Processed and saved combined file: 1YHQ27_combined.csv
# Processed and saved combined file: 1YO50_combined.csv
# Processed and saved combined file: 1YQM0_combined.csv
# Processed and saved combined file: 1YTY1_combined.csv
# Processed and saved combined file: 1YVP0_combined.csv
# Processed and saved combined file: 1ZAA0_combined.csv
# Processed and saved combined file: 1ZBL_M11_combined.csv
# Processed and saved combined file: 1ZET0_combined.csv
# Processed and saved combined file: 1ZM50_combined.csv
# Processed and saved combined file: 1ZME1_combined.csv
# Processed and saved combined file: 1ZNS0_combined.csv
# Processed and saved combined file: 1ZS42_combined.csv
# Processed and saved combined file: 1ZZI0_combined.csv
# Processed and saved combined file: 2A074_combined.csv
# Processed and saved combined file: 2A660_combined.csv
# Processed and saved combined file: 2A8V0_combined.csv
# Processed and saved combined file: 2ANR0_combined.csv
# Processed and saved combined file: 2AOQ0_combined.csv
# Processed and saved combined file: 2AQ40_combined.csv
# Processed and saved combined file: 2ATW0_combined.csv
# Processed and saved combined file: 2B3J1_combined.csv
# Processed and saved combined file: 2B9S0_combined.csv
# Processed and saved combined file: 2B9S1_combined.csv
# Processed and saved combined file: 2BCQ0_combined.csv
# Processed and saved combined file: 2BH20_combined.csv
# Processed and saved combined file: 2BNW0_combined.csv
# Processed and saved combined file: 2BOP0_combined.csv
# Processed and saved combined file: 2C4Q2_combined.csv
# Processed and saved combined file: 2C621_combined.csv
# Processed and saved combined file: 2C6Y0_combined.csv
# Processed and saved combined file: 2C7A0_combined.csv
# Processed and saved combined file: 2C9L0_combined.csv
# Processed and saved combined file: 2CV50_combined.csv
# Processed and saved combined file: 2D5V1_combined.csv
# Processed and saved combined file: 2D7D0_combined.csv
# Processed and saved combined file: 2DB33_combined.csv
# Processed and saved combined file: 2DGC0_combined.csv
# Processed and saved combined file: 2DLC0_combined.csv
# Processed and saved combined file: 2DP60_combined.csv
# Processed and saved combined file: 2DRA0_combined.csv
# Processed and saved combined file: 2DXI1_combined.csv
# Processed and saved combined file: 2E1C_M20_combined.csv
# Processed and saved combined file: 2EFW0_combined.csv
# Processed and saved combined file: 2EVI0_combined.csv
# Processed and saved combined file: 2EX50_combined.csv
# Processed and saved combined file: 2EZV1_combined.csv
# Processed and saved combined file: 2F8K0_combined.csv
# Processed and saved combined file: 2FCC1_combined.csv
# Processed and saved combined file: 2FKC1_combined.csv
# Processed and saved combined file: 2FQZ3_combined.csv
# Processed and saved combined file: 2FR41_combined.csv
# Processed and saved combined file: 2G1P0_combined.csv
# Processed and saved combined file: 2H1K0_combined.csv
# Processed and saved combined file: 2H270_combined.csv
# Processed and saved combined file: 2H7H1_combined.csv
# Processed and saved combined file: 2HAN1_combined.csv
# Processed and saved combined file: 2HAX0_combined.csv
# Processed and saved combined file: 2HDD0_combined.csv
# Processed and saved combined file: 2HEO0_combined.csv
# Processed and saved combined file: 2HVS1_combined.csv
# Processed and saved combined file: 2HVY2_combined.csv
# Processed and saved combined file: 2HVY3_combined.csv
# Processed and saved combined file: 2I060_combined.csv
# Processed and saved combined file: 2I131_combined.csv
# Processed and saved combined file: 2I5S0_combined.csv
# Processed and saved combined file: 2I820_combined.csv
# Processed and saved combined file: 2IH41_combined.csv
# Processed and saved combined file: 2IIE0_combined.csv
# Processed and saved combined file: 2IRF4_combined.csv
# Processed and saved combined file: 2IS60_combined.csv
# Processed and saved combined file: 2ISZ0_combined.csv
# Processed and saved combined file: 2JEA0_combined.csv
# Processed and saved combined file: 2JEA1_combined.csv
# Processed and saved combined file: 2JLY0_combined.csv
# Processed and saved combined file: 2NQB3_combined.csv
# Processed and saved combined file: 2NTC0_combined.csv
# Processed and saved combined file: 2NUG0_combined.csv
# Processed and saved combined file: 2O490_combined.csv
# Processed and saved combined file: 2OAA0_combined.csv
# Processed and saved combined file: 2OFI0_combined.csv
# Processed and saved combined file: 2OPF0_combined.csv
# Processed and saved combined file: 2OR11_combined.csv
# Processed and saved combined file: 2P0J1_combined.csv
# Processed and saved combined file: 2P2R0_combined.csv
# Processed and saved combined file: 2PI03_combined.csv
# Processed and saved combined file: 2PJP0_combined.csv
# Processed and saved combined file: 2PO10_combined.csv
# Processed and saved combined file: 2PYJ1_combined.csv
# Processed and saved combined file: 2Q2T0_combined.csv
# Processed and saved combined file: 2Q660_combined.csv
# Processed and saved combined file: 2QFJ0_combined.csv
# Processed and saved combined file: 2QHB1_combined.csv
# Processed and saved combined file: 2QKB0_combined.csv
# Processed and saved combined file: 2QL20_combined.csv
# Processed and saved combined file: 2QL21_combined.csv
# Processed and saved combined file: 2QOJ0_combined.csv
# Processed and saved combined file: 2QUX3_combined.csv
# Processed and saved combined file: 2R8S0_combined.csv
# Processed and saved combined file: 2R8S1_combined.csv
# Processed and saved combined file: 2RAM0_combined.csv
# Processed and saved combined file: 2RBF0_combined.csv
# Processed and saved combined file: 2UP10_combined.csv
# Processed and saved combined file: 2UWM0_combined.csv
# Processed and saved combined file: 2UZ40_combined.csv
# Processed and saved combined file: 2V3C2_combined.csv
# Processed and saved combined file: 2VE90_combined.csv
# Processed and saved combined file: 2VJV0_combined.csv
# Processed and saved combined file: 2VLA0_combined.csv
# Processed and saved combined file: 2VNU0_combined.csv
# Processed and saved combined file: 2VOA0_combined.csv
# Processed and saved combined file: 2VQE0_combined.csv
# Processed and saved combined file: 2VQE1_combined.csv
# Processed and saved combined file: 2VQE10_combined.csv
# Processed and saved combined file: 2VQE11_combined.csv
# Processed and saved combined file: 2VQE12_combined.csv
# Processed and saved combined file: 2VQE13_combined.csv
# Processed and saved combined file: 2VQE14_combined.csv
# Processed and saved combined file: 2VQE15_combined.csv
# Processed and saved combined file: 2VQE16_combined.csv
# Processed and saved combined file: 2VQE17_combined.csv
# Processed and saved combined file: 2VQE18_combined.csv
# Processed and saved combined file: 2VQE2_combined.csv
# Processed and saved combined file: 2VQE3_combined.csv
# Processed and saved combined file: 2VQE4_combined.csv
# Processed and saved combined file: 2VQE5_combined.csv
# Processed and saved combined file: 2VQE6_combined.csv
# Processed and saved combined file: 2VQE7_combined.csv
# Processed and saved combined file: 2VQE8_combined.csv
# Processed and saved combined file: 2VQE9_combined.csv
# Processed and saved combined file: 2VS81_combined.csv
# Processed and saved combined file: 2VTB0_combined.csv
# Processed and saved combined file: 2VW91_combined.csv
# Processed and saved combined file: 2VY10_combined.csv
# Processed and saved combined file: 2W361_combined.csv
# Processed and saved combined file: 2W420_combined.csv
# Processed and saved combined file: 2W7N0_combined.csv
# Processed and saved combined file: 2WBU0_combined.csv
# Processed and saved combined file: 2WIW1_combined.csv
# Processed and saved combined file: 2WQ60_combined.csv
# Processed and saved combined file: 2WT70_combined.csv
# Processed and saved combined file: 2WT71_combined.csv
# Processed and saved combined file: 2X1F0_combined.csv
# Processed and saved combined file: 2X6V0_combined.csv
# Processed and saved combined file: 2XCS1_combined.csv
# Processed and saved combined file: 2XM35_combined.csv
# Processed and saved combined file: 2XNR0_combined.csv
# Processed and saved combined file: 2XRZ1_combined.csv
# Processed and saved combined file: 2XS50_combined.csv
# Processed and saved combined file: 2XSD0_combined.csv
# Processed and saved combined file: 2YVH3_combined.csv
# Processed and saved combined file: 2Z3X2_combined.csv
# Processed and saved combined file: 2Z700_combined.csv
# Processed and saved combined file: 2ZKD0_combined.csv
# Processed and saved combined file: 2ZKO1_combined.csv
# Processed and saved combined file: 2ZUF0_combined.csv
# Processed and saved combined file: 3A461_combined.csv
# Processed and saved combined file: 3A4K0_combined.csv
# Processed and saved combined file: 3AAF1_combined.csv
# Processed and saved combined file: 3ADD0_combined.csv
# Processed and saved combined file: 3AGV0_combined.csv
# Processed and saved combined file: 3B391_combined.csv
# Processed and saved combined file: 3BAM0_combined.csv
# Processed and saved combined file: 3BEP1_combined.csv
# Processed and saved combined file: 3BM31_combined.csv
# Processed and saved combined file: 3BOY1_combined.csv
# Processed and saved combined file: 3BRF0_combined.csv
# Processed and saved combined file: 3BS10_combined.csv
# Processed and saved combined file: 3BSN0_combined.csv
# Processed and saved combined file: 3BSU1_combined.csv
# Processed and saved combined file: 3BT70_combined.csv
# Processed and saved combined file: 3BTY0_combined.csv
# Processed and saved combined file: 3C251_combined.csv
# Processed and saved combined file: 3C2I0_combined.csv
# Processed and saved combined file: 3C580_combined.csv
# Processed and saved combined file: 3CC220_combined.csv
# Processed and saved combined file: 3CFR0_combined.csv
# Processed and saved combined file: 3COQ1_combined.csv
# Processed and saved combined file: 3CRO1_combined.csv
# Processed and saved combined file: 3D2S1_combined.csv
# Processed and saved combined file: 3D2W0_combined.csv
# Processed and saved combined file: 3DD21_combined.csv
# Processed and saved combined file: 3DSD1_combined.csv
# Processed and saved combined file: 3DW91_combined.csv
# Processed and saved combined file: 3E541_combined.csv
# Processed and saved combined file: 3E6C0_combined.csv
# Processed and saved combined file: 3ECP0_combined.csv
# Processed and saved combined file: 3EQT0_combined.csv
# Processed and saved combined file: 3ER91_combined.csv
# Processed and saved combined file: 3EX76_combined.csv
# Processed and saved combined file: 3EX77_combined.csv
# Processed and saved combined file: 3EYI1_combined.csv
# Processed and saved combined file: 3F211_combined.csv
# Processed and saved combined file: 3FDQ0_combined.csv
# Processed and saved combined file: 3FHT1_combined.csv
# Processed and saved combined file: 3FOZ1_combined.csv
# Processed and saved combined file: 3G0Q0_combined.csv
# Processed and saved combined file: 3G0R0_combined.csv
# Processed and saved combined file: 3G730_combined.csv
# Processed and saved combined file: 3G9Y0_combined.csv
# Processed and saved combined file: 3GFI0_combined.csv
# Processed and saved combined file: 3GNA0_combined.csv
# Processed and saved combined file: 3GOX1_combined.csv
# Processed and saved combined file: 3GP80_combined.csv
# Processed and saved combined file: 3GPQ1_combined.csv
# Processed and saved combined file: 3GQC1_combined.csv
# Processed and saved combined file: 3GXQ0_combined.csv
# Processed and saved combined file: 3H0D0_combined.csv
# Processed and saved combined file: 3HAX0_combined.csv
# Processed and saved combined file: 3HSB2_combined.csv
# Processed and saved combined file: 3HTS0_combined.csv
# Processed and saved combined file: 3HXO0_combined.csv
# Processed and saved combined file: 3I0X0_combined.csv
# Processed and saved combined file: 3I5X0_combined.csv
# Processed and saved combined file: 3IAG0_combined.csv
# Processed and saved combined file: 3IAY0_combined.csv
# Processed and saved combined file: 3IEM0_combined.csv
# Processed and saved combined file: 3IGC0_combined.csv
# Processed and saved combined file: 3IGM0_combined.csv
# Processed and saved combined file: 3IKT1_combined.csv
# Processed and saved combined file: 3IMB3_combined.csv
# Processed and saved combined file: 3JR50_combined.csv
# Processed and saved combined file: 3JSO1_combined.csv
# Processed and saved combined file: 3JTG0_combined.csv
# Processed and saved combined file: 3JXD0_combined.csv
# Processed and saved combined file: 3JY10_combined.csv
# Processed and saved combined file: 3K0S0_combined.csv
# Processed and saved combined file: 3K490_combined.csv
# Processed and saved combined file: 3KDE0_combined.csv
# Processed and saved combined file: 3KET0_combined.csv
# Processed and saved combined file: 3KJP0_combined.csv
# Processed and saved combined file: 3KMS0_combined.csv
# Processed and saved combined file: 3KS82_combined.csv
# Processed and saved combined file: 3KXT0_combined.csv
# Processed and saved combined file: 3L2C0_combined.csv
# Processed and saved combined file: 3L4J0_combined.csv
# Processed and saved combined file: 3LAJ5_combined.csv
# Processed and saved combined file: 3LDY0_combined.csv
# Processed and saved combined file: 3LRR1_combined.csv
# Processed and saved combined file: 3M4A0_combined.csv
# Processed and saved combined file: 3M7N4_combined.csv
# Processed and saved combined file: 3M7N6_combined.csv
# Processed and saved combined file: 3M9E2_combined.csv
# Processed and saved combined file: 3MAQ0_combined.csv
# Processed and saved combined file: 3MDG0_combined.csv
# Processed and saved combined file: 3MFH0_combined.csv
# Processed and saved combined file: 3MGV3_combined.csv
# Processed and saved combined file: 3MIP1_combined.csv
# Processed and saved combined file: 3MJ00_combined.csv
# Processed and saved combined file: 3MLN1_combined.csv
# Processed and saved combined file: 3MVA0_combined.csv
# Processed and saved combined file: 3MX41_combined.csv
# Processed and saved combined file: 3MXA0_combined.csv
# Processed and saved combined file: 3N1I0_combined.csv
# Processed and saved combined file: 3NDH1_combined.csv
# Processed and saved combined file: 3NGO0_combined.csv
# Processed and saved combined file: 3NH21_combined.csv
# Processed and saved combined file: 3NNC0_combined.csv
# Processed and saved combined file: 3O1U0_combined.csv
# Processed and saved combined file: 3O3G0_combined.csv
# Processed and saved combined file: 3O7V0_combined.csv
# Processed and saved combined file: 3O8C0_combined.csv
# Processed and saved combined file: 3O9X0_combined.csv
# Processed and saved combined file: 3OA60_combined.csv
# Processed and saved combined file: 3OD86_combined.csv
# Processed and saved combined file: 3ODH2_combined.csv
# Processed and saved combined file: 3OIN0_combined.csv
# Processed and saved combined file: 3OR30_combined.csv
# Processed and saved combined file: 3OSF1_combined.csv
# Processed and saved combined file: 3PEY0_combined.csv
# Processed and saved combined file: 3PX70_combined.csv
# Processed and saved combined file: 3R9W0_combined.csv
# Processed and saved combined file: 3S3N0_combined.csv
# Processed and saved combined file: 3THV0_combined.csv
# Processed and saved combined file: 3U3Y0_combined.csv
# Processed and saved combined file: 3UBY0_combined.csv
# Processed and saved combined file: 3UMY0_combined.csv
# Processed and saved combined file: 3V740_combined.csv
# Processed and saved combined file: 3VAJ1_combined.csv
# Processed and saved combined file: 3VKE0_combined.csv
# Processed and saved combined file: 3VW30_combined.csv
# Processed and saved combined file: 4AL50_combined.csv
# Processed and saved combined file: 4BQA0_combined.csv
# Processed and saved combined file: 4BWJ0_combined.csv
# Processed and saved combined file: 4ED50_combined.csv
# Processed and saved combined file: 4F4W0_combined.csv
# Processed and saved combined file: 4GLX0_combined.csv
# Processed and saved combined file: 4HT90_combined.csv
# Processed and saved combined file: 4HUB10_combined.csv
# Processed and saved combined file: 4HUB16_combined.csv
# Processed and saved combined file: 4HUB24_combined.csv
# Processed and saved combined file: 4HUB25_combined.csv
# Processed and saved combined file: 4HUB8_combined.csv
# Processed and saved combined file: 4HUB9_combined.csv
# Processed and saved combined file: 4IBU0_combined.csv
# Processed and saved combined file: 4JYZ0_combined.csv
# Processed and saved combined file: 4K4Z2_combined.csv
# Processed and saved combined file: 4KLM0_combined.csv
# Processed and saved combined file: 4M0A0_combined.csv
# Processed and saved combined file: 4MKY3_combined.csv
# Processed and saved combined file: 4O3R0_combined.csv
# Processed and saved combined file: 6PAX0_combined.csv
# Processed and saved combined file: 9ANT1_combined.csv
# Processed and saved combined file: 2XZO0_combined.csv
# Processed and saved combined file: 2Y8W0_combined.csv
# Processed and saved combined file: 3B0U0_combined.csv
# Processed and saved combined file: 3POV0_combined.csv
# Processed and saved combined file: 3QMH0_combined.csv
# Processed and saved combined file: 3QWS0_combined.csv
# Processed and saved combined file: 3R2C1_combined.csv
# Processed and saved combined file: 3RMP0_combined.csv
# Processed and saved combined file: 3RN51_combined.csv
# Processed and saved combined file: 3RW61_combined.csv
# Processed and saved combined file: 3SM41_combined.csv
# Processed and saved combined file: 3SPD0_combined.csv
# Processed and saved combined file: 3SSC1_combined.csv
# Processed and saved combined file: 3T3O0_combined.csv
# Processed and saved combined file: 3T5N0_combined.csv
# Processed and saved combined file: 3U2E0_combined.csv
# Processed and saved combined file: 3U3W0_combined.csv
# Processed and saved combined file: 3UGO0_combined.csv
# Processed and saved combined file: 3VD60_combined.csv
# Processed and saved combined file: 3VJR0_combined.csv
# Processed and saved combined file: 3VOK0_combined.csv
# Processed and saved combined file: 3VYX0_combined.csv
# Processed and saved combined file: 3WBM0_combined.csv
# Processed and saved combined file: 3ZDB0_combined.csv
# Processed and saved combined file: 3ZGZ0_combined.csv
# Processed and saved combined file: 3ZH22_combined.csv
# Processed and saved combined file: 3ZVN0_combined.csv
# Processed and saved combined file: 4ATO0_combined.csv
# Processed and saved combined file: 4BXO1_combined.csv
# Processed and saved combined file: 4C8Y0_combined.csv
# Processed and saved combined file: 4E0J0_combined.csv
# Processed and saved combined file: 4EGZ1_combined.csv
# Processed and saved combined file: 4ESJ0_combined.csv
# Processed and saved combined file: 4EW00_combined.csv
# Processed and saved combined file: 4FPV0_combined.csv
# Processed and saved combined file: 4FZY1_combined.csv
# Processed and saved combined file: 4G0A2_combined.csv
# Processed and saved combined file: 4G920_combined.csv
# Processed and saved combined file: 4G921_combined.csv
# Processed and saved combined file: 4G922_combined.csv
# Processed and saved combined file: 4GCK0_combined.csv
# Processed and saved combined file: 4GJP0_combined.csv
# Processed and saved combined file: 4GZ02_combined.csv
# Processed and saved combined file: 4H5P3_combined.csv
# Processed and saved combined file: 4HIO0_combined.csv
# Processed and saved combined file: 4HLY1_combined.csv
# Processed and saved combined file: 4HOS0_combined.csv
# Processed and saved combined file: 4HP10_combined.csv
# Processed and saved combined file: 4HQB0_combined.csv
# Processed and saved combined file: 4HQE1_combined.csv
# Processed and saved combined file: 4HQX0_combined.csv
# Processed and saved combined file: 4I670_combined.csv
# Processed and saved combined file: 4II90_combined.csv
# Processed and saved combined file: 4ILL0_combined.csv
# Processed and saved combined file: 4IWR1_combined.csv
# Processed and saved combined file: 4IX70_combined.csv
# Processed and saved combined file: 4J7L0_combined.csv
# Processed and saved combined file: 4JBM0_combined.csv
# Processed and saved combined file: 4JCX0_combined.csv
# Processed and saved combined file: 4JNG3_combined.csv
# Processed and saved combined file: 4JRP0_combined.csv
# Processed and saved combined file: 4JZV0_combined.csv
# Processed and saved combined file: 4K960_combined.csv
# Processed and saved combined file: 4L0Y0_combined.csv
# Processed and saved combined file: 4L8H0_combined.csv
# Processed and saved combined file: 4LGT0_combined.csv
# Processed and saved combined file: 4LJ00_combined.csv
# Processed and saved combined file: 4LJR1_combined.csv
# Processed and saved combined file: 4LMG2_combined.csv
# Processed and saved combined file: 4LUP0_combined.csv
# Processed and saved combined file: 4M4O0_combined.csv
# Processed and saved combined file: 4M590_combined.csv
# Processed and saved combined file: 4MDX1_combined.csv
# Processed and saved combined file: 4NCA0_combined.csv
# Processed and saved combined file: 4NDH1_combined.csv
# Processed and saved combined file: 4NI70_combined.csv
# Processed and saved combined file: 4NKU0_combined.csv
# Processed and saved combined file: 4NM60_combined.csv
# Processed and saved combined file: 4OI00_combined.csv
# Processed and saved combined file: 4OOG0_combined.csv
# Processed and saved combined file: 4OOG2_combined.csv
# Processed and saved combined file: 4OWX1_combined.csv
# Processing completed!

# %%
import os
import pandas as pd
import numpy as np

# Paths to your folder containing combined CSV files and ID files
folder_path = 'output_features'  # Folder with the combined CSV files
train_ids_path = 'train_ids.txt'  # File containing train ID prefixes
test_ids_path = 'test_ids.txt'    # File containing test ID prefixes

# Paths to the DRNA_TRAIN and DRNA_TEST files that contain IDs and labels
train_labels_path = 'DRNA_TRAIN.csv'
test_labels_path = 'DRNA_TEST.csv'

# Step 1: Read the list of prefixes for training and testing
with open(train_ids_path, 'r') as f:
    train_ids = [line.strip() for line in f.readlines()]

with open(test_ids_path, 'r') as f:
    test_ids = [line.strip() for line in f.readlines()]

# Step 2: Load the sequence IDs and labels from the DRNA_TRAIN and DRNA_TEST files
train_labels_df = pd.read_csv(train_labels_path)  # Load as DataFrame
test_labels_df = pd.read_csv(test_labels_path)  # Load as DataFrame

# Step 3: Create helper functions to get labels based on the prefix
def get_label_for_id(prefix, df):
    """Retrieve the label (sequence of 0s and 1s) for a given ID prefix from the DataFrame."""
    row = df[df['id'] == prefix]  # Assuming the CSV has an 'id' column with prefixes
    if row.empty:
        return None  # If no match is found, return None
    return row['dna_label'].values[0]  # Assuming there's a 'label' column

# Initialize lists to hold CSV data rows for train and test sets
train_rows = []
test_rows = []

# Step 4: Loop through all CSV files in the folder and process them
for file_name in os.listdir(folder_path):
    if file_name.endswith('_combined.csv'):
        # Get the ID prefix (assuming the format is ID_combined.csv)
        prefix = file_name.split('_combined.csv')[0]

        # Load the CSV file as a 2D list (not a NumPy array)
        file_path = os.path.join(folder_path, file_name)
        data_array = pd.read_csv(file_path, header=None).values  # Load as a 2D array

        # Step 5: Get the corresponding label for the ID
        if prefix in train_ids:
            label = get_label_for_id(prefix, train_labels_df)
            if label is not None:
                train_rows.append([prefix, label] + data_array.flatten().tolist())
        elif prefix in test_ids:
            label = get_label_for_id(prefix, test_labels_df)
            if label is not None:
                test_rows.append([prefix, label] + data_array.flatten().tolist())
        else:
            print(f"Warning: Prefix {prefix} not found in train or test sets!")

# Step 6: Save train and test rows into separate CSV files
train_output_path = 'train_data_with_labels.csv'
test_output_path = 'test_data_with_labels.csv'

# Save train data to CSV
train_df = pd.DataFrame(train_rows)
train_df.to_csv(train_output_path, index=False, header=False)

# Save test data to CSV
test_df = pd.DataFrame(test_rows)
test_df.to_csv(test_output_path, index=False, header=False)

print(f"Processed and saved train data to {train_output_path}")
print(f"Processed and saved test data to {test_output_path}")
# Out:
# Processed and saved train data to train_data_with_labels.csv
# Processed and saved test data to test_data_with_labels.csv

# %%
import numpy as np
import pandas as pd
from pathlib import Path

def read_ids(file_path):
    with open(file_path, 'r') as f:
        return [line.strip() for line in f.readlines()]

def create_windows(data, window_size=9):
    # print(len(data))
    windows = []
    for i in range(0, len(data) - window_size + 1):
        window = data[i:i + window_size].to_numpy()
        windows.append(window)
    return np.array(windows)

def process_data(file_ids, label_csv, data_folder, window_size=9):
    data_list = []
    labels_list = []

    # Load the labels file
    labels_df = pd.read_csv(label_csv)

    # Process each file in the file_ids list
    for file_id in file_ids:
        file_path = data_folder / f"{file_id}_combined.csv"
        
        # Read the CSV file
        data = pd.read_csv(file_path, header=None)
        
        # Create windows from the data
        windows = create_windows(data, window_size=window_size)
        
        # Append the windows to data_list
        data_list.append(windows)

        # Get corresponding labels
        label_row = labels_df.loc[labels_df['id'] == file_id]
        labels = label_row['dna_label'].values[0]
        labels = [int(x) for x in labels]  # Convert to integer list
        
        # Skip the first and last 4 labels based on the window size
        labels = labels[4:len(labels) - 4]
        labels_list.append(labels)

    return np.array(data_list), np.array(labels_list)

# Paths and constants
train_ids_path = '/home/tzejet/drb_jet/train_ids.txt'
test_ids_path = '/home/tzejet/drb_jet/test_ids.txt'
train_labels_path = 'DRNA_TRAIN.csv'
test_labels_path = 'DRNA_TEST.csv'
data_folder = Path('/home/tzejet/drb_jet/output_features')  # Change this to the correct folder path

# Step 1: Read train and test file IDs
train_ids = read_ids(train_ids_path)
test_ids = read_ids(test_ids_path)

# Step 2: Process the train data and labels
train_data, train_label = process_data(train_ids, train_labels_path, data_folder)

# Step 3: Process the test data and labels
test_data, test_label = process_data(test_ids, test_labels_path, data_folder)

# Now train_data, train_label, test_data, test_label are ready for further use\
# Out:
# /tmp/ipykernel_1256826/1782520410.py:46: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data_list), np.array(labels_list)
# /tmp/ipykernel_1256826/1782520410.py:46: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data_list), np.array(labels_list)

# %%
# Initialize an empty list to store the flattened arrays
flattened_data = []

# Loop through each element in train_data
for sequence in train_data:
    # Reshape each (n, 9, 76) array to (n, 9 * 76)
    n, _, _ = sequence.shape
    flattened_sequence = sequence.reshape(n, 9 * 76)
    
    # Append to the list
    flattened_data.append(flattened_sequence)

# Concatenate all flattened sequences into a single array
# This results in a shape of (x, 9 * 76), where x is the total sum of n's
flattened_train_data = np.vstack(flattened_data)

# Now flattened_train_data is ready, and its shape will be (x, 9 * 76)
print(flattened_train_data.shape)

# Initialize an empty list to store the flattened arrays
flattened_data = []

# Loop through each element in train_data
for sequence in test_data:
    # Reshape each (n, 9, 76) array to (n, 9 * 76)
    n, _, _ = sequence.shape
    flattened_sequence = sequence.reshape(n, 9 * 76)
    
    # Append to the list
    flattened_data.append(flattened_sequence)

# Concatenate all flattened sequences into a single array
# This results in a shape of (x, 9 * 76), where x is the total sum of n's
flattened_test_data = np.vstack(flattened_data)

# Now flattened_train_data is ready, and its shape will be (x, 9 * 76)
print(flattened_test_data.shape)

flattened_train_label = np.concatenate(train_label).ravel()
print(flattened_train_label.shape)

flattened_test_label = np.concatenate(test_label).ravel()
print(flattened_test_label.shape)
# Out:
# (105004, 684)
# (19644, 684)
# (105004,)
# (19644,)

# %%
# Remove said rows if the corresponding labels at the index are '2'

# Find the indices of rows with label '2'
indices_to_remove = np.where(flattened_train_label == 2)[0]

# Remove the rows with label '2' from the flattened_train_data and flattened_train_label arrays
filtered_train_data = np.delete(flattened_train_data, indices_to_remove, axis=0)

filtered_train_label = np.delete(flattened_train_label, indices_to_remove)

indices_to_remove = np.where(flattened_test_label == 2)[0]

# Remove the rows with label '2' from the flattened_train_data and flattened_train_label arrays
filtered_test_data = np.delete(flattened_test_data, indices_to_remove, axis=0)

filtered_test_label = np.delete(flattened_test_label, indices_to_remove)

print(filtered_train_data.shape)
print(filtered_train_label.shape)
print(filtered_test_data.shape)
print(filtered_test_label.shape)
# Out:
# (100658, 684)
# (100658,)
# (18564, 684)
# (18564,)

# %%
def shuffle(random_state=None):
    positive_indices = np.where(filtered_train_label == 1)[0]
    negative_indices = np.where(filtered_train_label == 0)[0]

    # Determine the number of samples to subsample based on the smaller class
    n_samples = min(positive_indices.shape[0], negative_indices.shape[0]) 

    # Randomly select n_samples from both positive and negative indices
    positive_subsample_indices = np.random.choice(positive_indices, n_samples, replace=False)
    negative_subsample_indices = np.random.choice(negative_indices, n_samples, replace=False)

    # Concatenate the subsampled indices and then use them to create subsampled filtered_train_data and filtered_train_label
    subsample_indices = np.concatenate([positive_subsample_indices, negative_subsample_indices])
    filtered_train_data_subsampled = filtered_train_data[subsample_indices]
    filtered_train_label_subsampled = filtered_train_label[subsample_indices]
    print(filtered_train_data_subsampled.shape, filtered_train_label_subsampled.shape)

    shuffle_indices = np.random.permutation(len(filtered_train_data_subsampled))
    filtered_train_data_subsampled = filtered_train_data_subsampled[shuffle_indices]
    filtered_train_label_subsampled = filtered_train_label_subsampled[shuffle_indices]
    
    return filtered_train_data_subsampled, filtered_train_label_subsampled

filtered_train_data_subsampled, filtered_train_label_subsampled = shuffle()
# Out:
# (15244, 684) (15244,)

# %%
train_dataset = lgb.Dataset(filtered_train_data_subsampled, label=filtered_train_label_subsampled)

params = {
    'objective': 'binary',  # Binary classification
    'metric': 'binary_logloss',  # Metric to minimize
    'boosting_type': 'gbdt',  # Gradient Boosting Decision Trees
    'num_leaves': 50,  # Control model complexity, default is 31 (can be tuned)
    'learning_rate': 0.05,  # Controls how fast the model learns (can reduce to 0.01 for better performance)
}

num_round = 100

model = lgb.train(params, train_dataset, num_round)
# Out:
# [LightGBM] [Info] Number of positive: 7622, number of negative: 7622
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 112728
# [LightGBM] [Info] Number of data points in the train set: 15244, number of used features: 684
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, matthews_corrcoef

def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: purple' if v else '' for v in is_max]

# Define the range of threshold values
thresholds = np.arange(0.0, 1.00, 0.02)
y_pred_proba = model.predict(filtered_test_data)

# Initialize lists to store the results
results = {
    'Threshold': [],
    'MCC': [],
    'Sensitivity (Recall)': [],
    'Specificity': []
}

# Calculate metrics for each threshold
for threshold in thresholds:
    # Predict the class labels based on the current threshold
    y_pred = (y_pred_proba >= threshold).astype(int)
    
    # Calculate MCC
    mcc = matthews_corrcoef(filtered_test_label, y_pred)
    
    # Calculate Sensitivity (Recall)
    sensitivity = recall_score(filtered_test_label, y_pred)
    
    # Calculate Specificity
    tn, fp, fn, tp = confusion_matrix(filtered_test_label, y_pred).ravel()
    specificity = tn / (tn + fp)
    
    # Store the results
    results['Threshold'].append(threshold)
    results['MCC'].append(mcc)
    results['Sensitivity (Recall)'].append(sensitivity)
    results['Specificity'].append(specificity)

# Create a DataFrame from the results
results_df = pd.DataFrame(results)
results_df = results_df.round(2)
# Apply the highlight function only to the 'MCC' column
styled_results_df = results_df.style.format("{:.2f}").apply(highlight_max, subset=['MCC'], axis=0)

# Display the styled DataFrame
styled_results_df


# Optionally, save the DataFrame to a CSV file
# results_df.to_csv('threshold_metrics.csv', index=False)
# Out:
#     Threshold   MCC  Sensitivity (Recall)  Specificity
# 0        0.00  0.00                  1.00         0.00
# 1        0.02  0.00                  1.00         0.00
# 2        0.04  0.02                  1.00         0.01
# 3        0.06  0.05                  1.00         0.04
# 4        0.08  0.06                  1.00         0.08
# 5        0.10  0.08                  0.99         0.12
# 6        0.12  0.09                  0.98         0.16
# 7        0.14  0.10                  0.98         0.20
# 8        0.16  0.11                  0.97         0.24
# 9        0.18  0.12                  0.96         0.27
# 10       0.20  0.13                  0.95         0.31
# 11       0.22  0.13                  0.94         0.35
# 12       0.24  0.14                  0.93         0.38
# 13       0.26  0.15                  0.92         0.41
# 14       0.28  0.16                  0.91         0.44
# 15       0.30  0.16                  0.90         0.47
# 16       0.32  0.17                  0.88         0.50
# 17       0.34  0.18                  0.87         0.53
# 18       0.36  0.18                  0.85         0.56
# 19       0.38  0.19                  0.83         0.59
# 20       0.40  0.19                  0.81         0.62
# 21       0.42  0.20                  0.80         0.64
# 22       0.44  0.21                  0.78         0.67
# 23       0.46  0.21                  0.75         0.69
# 24       0.48  0.21                  0.73         0.71
# 25       0.50  0.22                  0.72         0.74
# 26       0.52  0.23                  0.70         0.76
# 27       0.54  0.23                  0.67         0.78
# 28       0.56  0.23                  0.64         0.80
# 29       0.58  0.23                  0.61         0.82
# 30       0.60  0.23                  0.57         0.83
# 31       0.62  0.23                  0.54         0.85
# 32       0.64  0.24                  0.51         0.87
# 33       0.66  0.24                  0.48         0.88
# 34       0.68  0.23                  0.44         0.90
# 35       0.70  0.23                  0.40         0.91
# 36       0.72  0.22                  0.36         0.93
# 37       0.74  0.21                  0.31         0.94
# 38       0.76  0.20                  0.27         0.95
# 39       0.78  0.20                  0.23         0.96
# 40       0.80  0.18                  0.18         0.97
# 41       0.82  0.16                  0.14         0.98
# 42       0.84  0.13                  0.09         0.99
# 43       0.86  0.11                  0.06         0.99
# 44       0.88  0.06                  0.02         1.00
# 45       0.90  0.05                  0.01         1.00
# 46       0.92 -0.00                  0.00         1.00
# 47       0.94  0.00                  0.00         1.00
# 48       0.96  0.00                  0.00         1.00
# 49       0.98  0.00                  0.00         1.00
